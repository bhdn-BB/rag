# %%
from app.services.documents_parser import DBNParser
from app.models.parameters import ChunkingParameters

# %%
DOCX_FILE = 'C:\\Users\\Roma\\Downloads\\_load_0-0-0-1968-20.docx'
PDF_FILE = 'C:\\Users\\Roma\\Downloads\\ПРАКТИЧНЕ ЗАНЯТТЯ 1.pdf'
URL = 'https://zakon.rada.gov.ua/laws/show/z1167-25#n17'

# %%
parser = DBNParser(ChunkingParameters())
content_docx = parser.load(DOCX_FILE, 'file')
content_pdf = parser.load(PDF_FILE, 'file')
content_url = parser.load(URL, 'url')
# Out:
# [INFO] 2026-01-28 15:17:44 - Loaded 1 documents from file: _load_0-0-0-1968-20.docx
# [INFO] 2026-01-28 15:17:44 - First chunk preview: НАЦІОНАЛЬНИЙ СТАНДАРТ УКРАЇНИ
#
# ДСТУ 9219:2023
#
# ТРУБИ СТАЛЕВІ ЗВАРНІ ДЛЯ МАГІСТРАЛЬНИХ ГАЗОНАФТОПРОВО...
# [INFO] 2026-01-28 15:17:45 - Chunking complete. Total chunks: 78
# [INFO] 2026-01-28 15:17:45 - First chunk preview: НАЦІОНАЛЬНИЙ СТАНДАРТ УКРАЇНИ
#
# ДСТУ 9219:2023
#
# ТРУБИ СТАЛЕВІ ЗВАРНІ ДЛЯ МАГІСТРАЛЬНИХ ГАЗОНАФТОПРОВО...
# Ignoring wrong pointing object 6 0 (offset 0)
# Ignoring wrong pointing object 8 0 (offset 0)
# Ignoring wrong pointing object 10 0 (offset 0)
# Ignoring wrong pointing object 12 0 (offset 0)
# Ignoring wrong pointing object 14 0 (offset 0)
# Ignoring wrong pointing object 16 0 (offset 0)
# Ignoring wrong pointing object 27 0 (offset 0)
# Ignoring wrong pointing object 37 0 (offset 0)
# Ignoring wrong pointing object 39 0 (offset 0)
# Ignoring wrong pointing object 49 0 (offset 0)
# ...

# %%
print(
    f'========================================='
    f'DOCX content'
    f'========================================='
)
content_docx[0]
# Out:
# =========================================DOCX content=========================================
# Document(metadata={'source': '_load_0-0-0-1968-20.docx', 'file_type': '.docx', 'chunk_len': 713, 'is_table': False}, page_content='НАЦІОНАЛЬНИЙ СТАНДАРТ УКРАЇНИ\n\nДСТУ 9219:2023\n\nТРУБИ СТАЛЕВІ ЗВАРНІ ДЛЯ МАГІСТРАЛЬНИХ ГАЗОНАФТОПРОВОДІВ\nТехнічні умови\n\nВідповідає офіційному тексту\n\nЗ питань придбання\nофіційного видання звертайтесь до національного органу \nстандартизації (ДП «УкрНДНЦ» http://uas.gov.ua)\n\nПЕРЕДМОВА\n\n1 РОЗРОБЛЕНО: Державне підприємство «Науково-дослідний та конструкторсько-технологічний інститут трубної промисловості ім. Я.Ю. Осади» (ДП «НДТІ»), Технічний комітет стандартизації «Труби сталеві та балони» (ТК 8)\n\n2 ПРИЙНЯТО ТА НАДАНО ЧИННОСТІ: наказ Державного підприємства «Український науково-дослідний і навчальний центр проблем стандартизації, сертифікації та якості» (ДП «УкрНДНЦ») від 27 квітня 2023 р. № 80 з 2023-07-01')

# %%
print(
    f'========================================='
    f'PDF content'
    f'========================================='
)
content_pdf[0]
# Out:
# =========================================PDF content=========================================
# ...

# %%
print(
    f'========================================='
    f'URL content'
    f'========================================='
)
content_url[0]
# Out:
# =========================================URL content=========================================
# ...
